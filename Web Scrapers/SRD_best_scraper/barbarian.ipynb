# %%
# discoveries
import requests
import json
from bs4 import BeautifulSoup

BASE_URL = "https://www.d20pfsrd.com"
DISCOVERIES_URL = BASE_URL + "/classes/core-classes/barbarian/rage-powers/"
a_tag = "rage-powers"
ACCEPTABLE_KEYS = ["Prerequisite", "Benefit"]  # Add more keys if needed
title = "Barbarian"

def grab_page_data(URL, a_tag):
    """Fetches the main page and extracts all valid discovery links."""
    response = requests.get(URL)
    soup = BeautifulSoup(response.text, "html.parser")

    links = []
    for a in soup.find_all('a', href=True):
        if a_tag in a['href']:
            href = a['href']
            if href.startswith("/"):
                href = BASE_URL + href  # Convert relative URL to absolute
            links.append(href)

    return links

import re
import requests
from bs4 import BeautifulSoup

import requests
from bs4 import BeautifulSoup

def extract_formatted_data(link):
    """Extracts structured content in the desired JSON format."""
    response = requests.get(link)
    soup = BeautifulSoup(response.text, "html.parser")

    h1_tag = soup.find("h1")
    if not h1_tag:
        return None

    title = h1_tag.get_text(strip=False)  # Get the discovery title
    content_dict = {}  # Dictionary to store extracted data

    # Remove <div> elements with class 'section15'
    for section in soup.find_all("div", class_="section15"):
        section.decompose()  # Remove the element from the tree    

    node = h1_tag.find_next_sibling()  # Start reading after <h1>

    current_key = None  # Track section titles (e.g., "Prerequisite", "Benefit")

    # Skip any <div> tags that come before the first <p> tag after the <h1>
    while node and node.name not in ["p", "div"]:  # Search for the first <p> or <div> after <h1>
        node = node.find_next_sibling()

    # Now that we've found the first meaningful content or ended up with None
    while node:
        if node.name == "p":  # Paragraphs
            text = node.get_text(strip=False)
            for key in ACCEPTABLE_KEYS:
                if text.startswith(key):  # Match section headers
                    current_key = key
                    content_dict[current_key] = text[len(key):].strip(": ").replace(key, " ")
                    break
            else:
                if current_key:  # Append to the last detected section
                    content_dict[current_key] += " " + text
                    
        
        # If node is a <div> tag, search for any nested <p> tags inside it
        elif node.name == "div":
            # Search for any nested <p> tags inside the <div>
            nested_p = node.find_all("p")
            if nested_p:  # Only process the <div> if it contains <p> tags
                for p_tag in nested_p:
                    text = p_tag.get_text(strip=False)
                    for key in ACCEPTABLE_KEYS:
                        if text.startswith(key):  # Match section headers
                            current_key = key
                            content_dict[current_key] = text[len(key):].strip(": ").replace(key, " ")
                            break
                    else:
                        if current_key:  # Append to the last detected section
                            content_dict[current_key] += " " + text

        # Move to the next sibling after processing the current node
        node = node.find_next_sibling()

    return {title: content_dict}  # Return structured JSON with the title as the key

def clean_data(data):
    if isinstance(data, dict):
        for key, value in data.items():
            data[key] = clean_data(value)
    elif isinstance(data, list):
        for idx, value in enumerate(data):
            data[idx] = clean_data(value)
    elif isinstance(data, str):
        data = data.replace("(s): ", ""). replace("(s) ", "").replace("s: ", "")
    return data

# Fetch all links
links = grab_page_data(DISCOVERIES_URL, a_tag)

# Process each discovery page
pre_json_data = {}

# counter = 0
for link in links:
    print(f"\nExtracting from: {link}\n")
    extracted_data = extract_formatted_data(link)
    if extracted_data:
        pre_json_data.update(extracted_data)

    # counter += 1
    # if counter >= 20:
    #     break

pre_json_data = clean_data(pre_json_data)

# Save to JSON file
with open(f"{title}.json", "w", encoding="utf-8") as json_file:
    json.dump(pre_json_data, json_file, indent=2, ensure_ascii=False)

# Print final JSON output
print(json.dumps(pre_json_data, indent=2, ensure_ascii=False))
# Out:
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/beast-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/dragon-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-blood/
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ancestor-totem-lesser-su/
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ancestor-totem-su/
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ancestor-totem-greater-su/
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/armor-ripper
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/atavism-totem-lesser-su/
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/atavism-totem-su/
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/atavism-totem-greater-su/
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/auspicious-mark-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/battle-roar-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/intimidating-glare-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/intimidating-glare-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/beast-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/beast-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/beast-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/beast-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/beast-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/bestial-climber-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-climber-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/bestial-leaper-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-leaper-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/bestial-swimmer-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-swimmer-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/bleeding-blow-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/powerful-blow-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/powerful-blow-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/bloody-bite-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/bloody-fist-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/boar-s-charge
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/boasting-taunt-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/body-bludgeon-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/brawler
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/brawler-greater
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/brawler
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/breathtaker-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/celestial-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/celestial-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/celestial-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/celestial-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/chaos-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/chaos-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/chaos-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/chaos-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/chaos-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/clear-mind-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/come-and-get-me-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/crippling-blow-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/powerful-blow-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/powerful-blow-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/cult-totem-lesser-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/cult-totem-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/cult-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/daemon-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/daemon-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/daemon-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/deadly-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/deathless-frenzy
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/disemboweling-tusks
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/disruptive
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/superstition-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/dragon-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/intimidating-glare-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/dragon-totem-resilience-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/dragon-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/dragon-totem-wings-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/dragon-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/dragon-totem-resilience-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/eater-of-magic-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/superstition-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/elemental-rage-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/elemental-rage-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/elemental-rage-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/elemental-rage-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/elemental-rage-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/energy-absorption-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/energy-resistance-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/energy-eruption-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/energy-absorption-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/energy-resistance-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/energy-resistance-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/energy-resistance-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fearless-rage-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/feasting-bite-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/feast-of-blood-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/bloody-fist-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-beast-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-beast-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-beast-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-mount-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-mount-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-mount-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-trample-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-mount-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-trample-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-trample-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fiend-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fiend-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fiend-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fiend-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fiend-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fierce-fortitude-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fight-response-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/flesh-wound-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/fueled-by-vengeance
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/gearbreaker-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/smasher-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ghost-rager-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/superstition-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/good-for-what-ails-you-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/greater-animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ground-breaker-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ground-breaker-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ground-breaker-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ground-breaker-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/guarded-life-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/guarded-life-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/guarded-life-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/guarded-stance-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hive-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hive-totem-resilience-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hive-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hive-totem-toxicity-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hive-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hive-totem-resilience-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hurling-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hurling-lesser-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hurling-greater-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hurling-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hurling-lesser-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hurling-charge-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/hurling-lesser-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/impelling-disarm-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/increased-damage-reduction-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/inspire-ferocity-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/reckless-abandon-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/internal-fortitude-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/intimidating-glare-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/knockback-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/knockdown-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/lethal-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/deadly-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/linnorm-death-curse-crag-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/linnorm-death-curse-crag-su-1
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/linnorm-death-curse-fjord-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/linnorm-death-curse-ice-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/linnorm-death-curse-taiga-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/linnorm-death-curse-tarn-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/linnorm-death-curse-tor-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/liquid-courage-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/low-light-vision-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/mighty-swing-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/moment-of-clarity-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/moon-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/moon-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/moon-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/night-vision-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/low-light-vision-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/no-escape-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/overbearing-advance-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/overbearing-onslaught-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/overbearing-advance-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/penetrating-bite-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/perfect-clarity-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/moment-of-clarity-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/powerful-blow-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/primal-scent-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/scent-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/quick-reflexes-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-climber-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-flier-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-leaper-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-grappler-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-leaper-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/raging-swimmer-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/reckless-abandon-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/reflexive-dodge-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/rolling-dodge-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/rolling-dodge-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/regenerative-vigor-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/renewed-vigor-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/renewed-vigor-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/renewed-life-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/renewed-vitality-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/renewed-vigor-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/renewed-vitality-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/renewed-vigor-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/roaring-drunk-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/rolling-dodge-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/roused-anger-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/savage-dirty-trick-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/savage-intuition
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/savage-jaw-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/animal-fury-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/scent-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/sharpened-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/smasher-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spell-sunder-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/witch-hunter-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spellbreaker
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/disruptive
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spire-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spire-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spire-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spirit-steed-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ferocious-mount-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spirit-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spirit-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spirit-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spirit-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spirit-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/sprint-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/swift-foot-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/staggering-drunk-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/strength-surge-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/sunder-enchantment-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/spell-sunder-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/superstition-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/surprise-accuracy-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/swift-foot-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/terrifying-howl-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/intimidating-glare-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/ultimate-clarity-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/moment-of-clarity-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/perfect-clarity-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/unexpected-strike-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/water-sense-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/witch-hunter-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/superstition-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/world-serpent-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/world-serpent-spirit-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/world-serpent-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/world-serpent-totem-unity-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/world-serpent-spirit-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-rage-powers/world-serpent-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/lunar-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/lunar-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/lunar-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/lunar-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/lunar-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/shadow-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/shadow-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/shadow-totem-greater-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/shadow-totem-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-ascension-games-llc/shadow-totem-lesser-su
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-forest-guardian-press
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-forest-guardian-press/death-totem
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-forest-guardian-press/death-totem-lesser
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-forest-guardian-press/death-totem-greater
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-forest-guardian-press/death-totem
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-forest-guardian-press/death-totem-lesser
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-forest-guardian-press/death-totem-lesser
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-fans-united-rage-powers
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/paizo-fans-united-rage-powers/raging-skald-ex
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/radiance-house-rage-powers
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/radiance-house-rage-powers/improved-totemic-alignment
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/radiance-house-rage-powers/totemic-mettle
#
#
# Extracting from: https://www.d20pfsrd.com/classes/core-classes/barbarian/rage-powers/rage-powers-samurai-sheepdog/
#
# {
#   "Beast Totem (Su)": {
#     "Prerequisite": "Barbarian 6, lesser beast totem rage power",
#     "Benefit": "While raging, the barbarian gains a +1 natural armor bonus. This bonus increases by +1 for every four levels the barbarian has attained."
#   },
#   "Page Not Found - dragon-totem-su": {},
#   "Rage Powers: Blood": {},
#   "Ancestor Totem, Lesser (Su)": {
#     "Benefit": "When she enters a rage, the barbarian selects a skill of her choice, which must be one she can use while raging, such as Climb or Intimidate. While raging, she gains a +2 insight bonus to the chosen skill."
#   },
#   "Ancestor Totem (Su)": {
#     "Prerequisite": "Barbarian 6, lesser ancestor totem rage power",
#     "Benefit": "The barbarianâs insight bonus to her chosen skill increases to +4. The barbarian can now select any skill to receive this bonus, even a Charisma-, Dexterity-, or Intelligence-based skill or a skill that requires patience or concentration; if she selects such a skill, she can use it even while raging.Â "
#   },
#   "Ancestor Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 10, ancestor totem rage power",
#     "Benefit": "The barbarianâs insight bonus to her chosen skill increases to +6. Once per rage, she can spend one round of rage as an immediate action to reroll a skill check in the chosen skill. She must take the result of the second roll, even if it is lower."
#   },
#   "Animal Fury (Ex)": {
#     "Benefit": "While raging, the barbarian gains a bite attack. If used as part of a full attack action, the bite attack is made at the barbarian’s full base attack bonus â5. If the bite hits, it deals 1d4 points of damage (assuming the barbarian is Medium; 1d3 points of damage if Small) plus half the barbarian’s Strength modifier. A barbarian can make a bite attack as part of the action to maintain or break free from a grapple. This attack is resolved before the grapple check is made. If the bite attack hits, any grapple checks made by the barbarian against the target this round are at a +2 bonus."
#   },
#   "Armor Ripper": {
#     "Benefit": "While raging, you gain a +2 bonus on combat maneuver checks made to sunder with any of your natural attacks. Special: This rage power is available to wereboars, wereboar-kin and those who associate with these creatures."
#   },
#   "Atavism Totem, Lesser (Su)": {
#     "Benefit": "The barbarian gains a bite attack; if she already has a bite attack, it deals damage as if the barbarian were one size larger."
#   },
#   "Atavism Totem (Su)": {
#     "Prerequisite": "Barbarian 6",
#     "Benefit": "The barbarian gains ferocity."
#   },
#   "Atavism Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 10",
#     "Benefit": "The barbarian gains trample."
#   },
#   "Auspicious Mark (Su)": {
#     "Benefit": "The barbarian has been marked by the spirits, as indicated by an impressive tattoo, scar, or birthmark she possesses. Once per rage, as a swift action that costs 2 rounds of rage, the barbarian can call upon the spiritsâ favor. Using auspicious mark grants her a +1d6 bonus on one d20 roll she has just made. She can call on the auspicious mark after seeing the result of the d20 roll."
#   },
#   "Battle Roar (Su)": {
#     "Prerequisite": "Barbarian 6, intimidating glare",
#     "Benefit": "When the character successfully demoralizes an opponent using intimidating glare, he also deals 1d6 points of sonic damage to that opponent."
#   },
#   "Intimidating Glare (Ex)": {
#     "Benefit": "The barbarian can make an Intimidate check against one adjacent foe as a move action. If the barbarian successfully demoralizes her opponent, the foe is shaken for 1d4 rounds + 1 round for every 5 points by which the barbarian’s check exceeds the DC."
#   },
#   "Beast Totem, Lesser (Su)": {
#     "Benefit": "While raging, the barbarian gains two claw attacks. These attacks are considered primary attacks and are made at the barbarianâs full base attack bonus. The claws deal 1d6 points of slashing damage (1d4 if Small) plus the barbarianâs Strength modifier."
#   },
#   "Beast Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 10, beast totem rage power",
#     "Benefit": "While raging, the barbarian gains the pounce special ability, allowing her to make a full attack at the end of a charge. In addition, the damage from her claws increases to 1d8 (1d6 if Small) and the claws deal x 3 damage on a critical hit. FAQ If a creature with pounce is under a slow effect, and it charges, does it still get its full attack from pounce? According to the rules as written, pounce would allow the creature its full attack, despite the slow effect. (This happens because there is no “partial charge” action in the Pathfinder RPG.) Source"
#   },
#   "Bestial Climber (Ex)": {
#     "Prerequisite": "Barbarian 6, raging climber rage power",
#     "Benefit": "While raging, the barbarian gains a natural climb speed equal to her land speed."
#   },
#   "Raging Climber (Ex)": {
#     "Benefit": "When raging, the barbarian adds her level as an enhancement bonus on all Climb skill checks."
#   },
#   "Bestial Leaper (Ex)": {
#     "Prerequisite": "Barbarian 6, raging leaper rage power",
#     "Benefit": "While raging, the barbarian can take a move action to move and can take her normal standard action at any point during the move."
#   },
#   "Raging Leaper (Ex)": {
#     "Benefit": "When raging, the barbarian adds her level as an enhancement bonus on all Acrobatics skill checks made to jump. When making a jump in this way, the barbarian is always considered to have a running start."
#   },
#   "Bestial Swimmer (Ex)": {
#     "Prerequisite": "Barbarian 6, raging swimmer rage power",
#     "Benefit": "While raging, the barbarian gains a natural swim speed equal to her normal land speed."
#   },
#   "Raging Swimmer (Ex)": {
#     "Benefit": "When raging, the barbarian adds her level as an enhancement bonus on all Swim skill checks."
#   },
#   "Bleeding Blow (Ex)": {
#     "Prerequisite": "Barbarian 8, powerful blow rage power",
#     "Benefit": "When she uses her powerful blow rage power, the barbarian also deals bleed damage equal to her bonus damage with the powerful blow. This bleed damage bypasses damage reduction."
#   },
#   "Powerful Blow (Ex)": {
#     "Benefit": "The barbarian gains a +1 bonus on a single damage roll. This bonus increases by +1 for every 4 levels the barbarian has attained. This power is used as a swift action before the roll to hit is made. Special: This power can only be used once per rage."
#   },
#   "Bloody Bite (Ex)": {
#     "Prerequisite": "Half-orc, animal fury rage power or a natural bite attack",
#     "Benefit": "The barbarian’s bite attack deals 1d6 points of bleed damage in addition to its other effects."
#   },
#   "Bloody Fist (Ex)": {
#     "Prerequisite": "Barbarian 12",
#     "Benefit": "While raging, the barbarian may attempt to punch through an opponent’s flesh and rip out one of its vital organs. In order to do so, the barbarian must confirm a critical hit against an opponent with a natural attack or unarmed strike. The barbarian deals damage as normal for a critical hit and the opponent must succeed at a Fortitude save (DC = 10 + 1/2 the barbarian’s class level + the barbarian’s Strength modifier) or take 1d4 points of Constitution damage as one of its vital organs is ripped free from its body. This power can only be used once per rage."
#   },
#   "Boar’s Charge": {
#     "Prerequisite": "Barbarian 12",
#     "Benefit": "While raging, when you hit with a gore attack as part of a charge, you automatically score a critical threat. You must still confirm the critical hit as normal. Special: This rage power is available to wereboars, wereboar-kin and those who associate with these creatures."
#   },
#   "Boasting Taunt (Ex)": {
#     "Prerequisite": "Barbarian 6",
#     "Benefit": "While raging, the barbarian can incite a creature to attack her by making an Intimidate check to demoralize. If the check succeeds, the target is also shaken as long as the barbarian is visible and raging or until it makes a melee attack against the barbarian. The barbarian receives a +2 circumstance bonus on this check for every alcoholic drink she has consumed during this rage. This is a language-dependent mind-affecting effect, and it relies on audible components."
#   },
#   "Body Bludgeon (Ex)": {
#     "Prerequisite": "Barbarian 10",
#     "Benefit": "While raging, if the barbarian pins an opponent that is smaller than her, she can then use that opponent as a two-handed improvised weapon that deals 1d8 points of bludgeoning damage, assuming the opponent is sized Small. Larger or smaller creatures used as a bludgeon deal damage based on their size using this base damage. A size Tiny creature deals 1d6 points of damage, a size Medium creature deals 1d10 points of damage, and so on. The barbarian can make a single attack using the pinned opponent as part of the action she uses to maintain the grapple, using her highest attack bonus. Whenever the barbarian hits using the pinned opponent as a weapon, she deals damage to her target normally, and the grappled opponent used as a bludgeon also takes the same damage she dealt to the target. If the pinned opponent is unable to resist being pinned for any reason, the barbarian can use that opponent as an improvised weapon without grappling or pinning the opponent, until the creature is reduced to 0 or fewer hit points, at which point the creature becomes useless as an improvised weapon."
#   },
#   "Brawler": {
#     "Benefit": "While raging, the barbarian is treated as if she has Improved Unarmed Strike. If she already has the feat, her unarmed strikes deal 1d6 points of damage (1d4 if she is Small)."
#   },
#   "Brawler, Greater": {
#     "Prerequisite": "Brawler rage power",
#     "Benefit": "While raging, the barbarian is treated as if she has Two-Weapon Fighting when making unarmed strike attacks."
#   },
#   "Breathtaker (Ex)": {
#     "Benefit": "While raging, whenever you make a successful melee attack against an opponent that is holding its breath, in addition to any other effects caused by that attack, the opponent loses a number of rounds of breath equal to your Strength modifier."
#   },
#   "Celestial Totem, Lesser (Su)": {},
#   "Celestial Totem (Su)": {
#     "Prerequisite": "Barbarian 8 This effect bestows upon the barbarian a halo of gleaming light that shines as if it were daylight and triggers an invisibility purge effect in the barbarian’s square and each adjacent square. The invisibility purge only affects non-good creatures."
#   },
#   "Celestial Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 12, celestial totem While raging, the barbarian gains spell resistance equal to 11 + the barbarian’s class level against spells with the evil descriptor. She also gains a +2 bonus on all saving throws against spells and effects from evil creatures."
#   },
#   "Chaos Totem, Lesser (Su)": {
#     "Benefit": "While raging, the barbarian gains a +1 deflection bonus to AC against the attacks of lawful creatures and a +1 resistance bonus on saving throws against confusion, insanity, polymorph, and effects with the lawful descriptor. This bonus increases by +1 for each chaos totem rage power she possesses."
#   },
#   "Chaos Totem (Su)": {
#     "Prerequisite": "Barbarian 6, lesser chaos totem rage power",
#     "Benefit": "While raging, the barbarianâs form becomes infused with chaos. She gains a +4 bonus on Escape Artist checks and has a 25% chance to ignore extra damage from critical hits and sneak attacks."
#   },
#   "Chaos Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 10, chaos totem rage power",
#     "Benefit": "While raging, the barbarian gains DR/lawful equal to 1/2 her barbarian level. Her weapons and natural weapons are considered chaotic for the purpose of overcoming damage reduction."
#   },
#   "Clear Mind (Ex)": {
#     "Prerequisite": "Barbarian 8",
#     "Benefit": "A barbarian may reroll a failed Will save. This power is used as an immediate action after the first save is attempted, but before the results are revealed by the GM. The barbarian must take the second result, even if it is worse. Special: This power can only be used once per rage."
#   },
#   "Come and Get Me (Ex)": {
#     "Prerequisite": "Barbarian 12",
#     "Benefit": "While raging, as a free action the barbarian may leave herself open to attack while preparing devastating counterattacks. Enemies gain a +4 bonus on attack and damage rolls against the barbarian until the beginning of her next turn, but every attack against the barbarian provokes an attack of opportunity from her, which is resolved prior to resolving each enemy attack."
#   },
#   "Crippling Blow (Ex)": {
#     "Prerequisite": "Barbarian 8, powerful blow",
#     "Benefit": "When using her powerful blow rage power, the barbarian can forgo the normal bonus to damage (including any bleed damage granted by the bleeding blow rage power or similar boosts to the damage of the powerful blow rage power) and instead deals 1 point of ability damage to the targetâs Strength or Dexterity score for every four class levels the barbarian has attained. The target can attempt a Fortitude saving throw (DC 10 + 1/2 the barbarian’s level + the barbarian’s Strength modifier) to halve this ability damage."
#   },
#   "Cult Totem, Lesser (Ex)": {
#     "Benefit": "While the barbarian is raging, any morale bonuses or bonuses for flanking she gains on attacks rolls are added to her damage rolls instead of her attack rolls. They are still morale bonuses, and they donât stack with other morale bonuses on damage rolls."
#   },
#   "Cult Totem (Ex)": {
#     "Prerequisite": "Barbarian 6, lesser cult totem rage power",
# ...
#   },
#   "Sharpened Accuracy (Ex)": {
#     "Prerequisite": "Barbarian 8, surprise accuracy rage power",
#     "Benefit": "When using her surprise accuracy rage power, the barbarian ignores the miss chance for concealment and treats total concealment as concealment. She also ignores cover penalties except those from total cover."
#   },
#   "Spell Sunder (Su)": {
#     "Prerequisite": "Barbarian 6, witch hunter rage power",
#     "Benefit": "Once per rage, the barbarian can attempt to sunder an ongoing spell effect by succeeding at a combat maneuver check. For any effect other than one on a creature, the barbarian must make her combat maneuver check against a CMD of 15 plus the effectâs caster level. To sunder an effect on a creature, the barbarian must succeed at a normal sunder combat maneuver against the creatureâs CMD + 5, ignoring any miss chance caused by a spell or spell-like ability. If successful, the barbarian suppresses the effect for 1 round, or 2 rounds if she exceeded the CMD by 5 to 9. If she exceeds the CMD by 10 or more, the effect is dispelled."
#   },
#   "Witch Hunter (Ex)": {
#     "Prerequisite": "Superstition rage power",
#     "Benefit": "While raging, the barbarian gains a +1 bonus on damage rolls against creatures possessing spells or spell-like abilities. This damage bonus increases by +1 for every four levels the barbarian has obtained."
#   },
#   "Spellbreaker": {
#     "Prerequisite": "Barbarian 12, disruptive rage power",
#     "Benefit": "When raging, the barbarian gains Spellbreaker as a bonus feat. A barbarian must have the Disruptive rage power and be at least 12th level to select this rage power."
#   },
#   "Spire Totem (Su)": {
#     "Prerequisite": "Barbarian 6, lesser spire totem rage power",
#     "Benefit": "While raging, the barbarian takes no penalties for using a weapon to deal nonlethal damage. When dealing nonlethal damage, the barbarian adds a bonus equal to half her barbarian level on her damage rolls. A barbarian must have the lesser spire totem rage power and be at least 6th level to select this rage power."
#   },
#   "Spire Totem, Greater (Su)": {
#     "Prerequisite": "BarbarianÂ 10, spire totem rage power",
#     "Benefit": "While the barbarian is raging, all allies within 30 feet gain a +2 morale bonus on Will saves. When attempting a Will save against a fear effect, all allies within this area can roll twice and use the better result."
#   },
#   "Spire Totem, Lesser (Su)": {
#     "Benefit": "While raging, the barbarian gains a +1 morale bonus on attacks against any creature that has targeted one of her allies with an attack or a harmful spell within the last round."
#   },
#   "Spirit Steed (Su)": {
#     "Prerequisite": "Barbarian 6, ferocious mount rage power",
#     "Benefit": "While raging and mounted, the barbarianâs mount gains DR/magic equal to 1/2 the barbarianâs level. The mountâs natural weapons count as magical for the purpose of overcoming damage reduction."
#   },
#   "Spirit Totem (Su)": {
#     "Prerequisite": "Barbarian 6, lesser spirit totem rage power",
#     "Benefit": "While raging, the spirits that surround the barbarian make it difficult for her enemies to see her. The spirits grant the barbarian a 20% miss chance against ranged attacks and melee attacks made by creatures that are not adjacent to the barbarian (typically due to reach)."
#   },
#   "Spirit Totem, Lesser (Su)": {
#     "Benefit": "While raging, the barbarian is surrounded by spirit wisps that harass her foes. These spirits make one slam attack each round against a living foe that is adjacent to the barbarian. This slam attack is made using the barbarianâs full base attack bonus, plus the barbarianâs Charisma modifier. The slam deals 1d4 points of negative energy damage, plus the barbarianâs Charisma modifier. Editor’s Note Who decides who the spirits attack, and what effects affect the spirits? The barbarian decides who the spirits attack each round. The spirits are not affected by effects that aid their attacks or damage (such as bardic performance or bless) or penalize their attacks or damage (such as bane or darkness). The spirits always strike from your direction. They do not get flanking bonuses or help a combatant get one. [Source]"
#   },
#   "Spirit Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 10, spirit totem rage power",
#     "Benefit": "While raging, the spirits that surround the barbarian become dangerous to any enemy adjacent to the barbarian. Living enemies adjacent to the barbarian at the start of her turn take 1d8 points of negative energy damage. In addition, the spirit wisps can now attack foes that are up to 15 feet away from the barbarian and the slam attack deals 1d6 points of negative energy damage. Editor’s Note Who decides who the spirits (from Lesser Spirit Totem) attack, and what effects affect the spirits? The barbarian decides who the spirits attack each round. The spirits are not affected by effects that aid their attacks or damage (such as bardic performance or bless) or penalize their attacks or damage (such as bane or darkness). The spirits always strike from your direction. They do not get flanking bonuses or help a combatant get one. [Source]"
#   },
#   "Sprint (Ex)": {
#     "Prerequisite": "Barbarian 4, swift foot rage power",
#     "Benefit": "Once per rage, the barbarian can use a single full-round run action to move up to 6 times her speed or a single full-round charge action to move up to 3 times her speed."
#   },
#   "Swift Foot (Ex)": {
#     "Benefit": "The barbarian gains a 5-foot enhancement bonus to her speed. This increase is always active while the barbarian is raging. Special: A barbarian can select this rage power up to three times. Its effects stack."
#   },
#   "Staggering Drunk (Ex)": {
#     "Benefit": "While raging, a barbarian gains a +1 dodge bonus to AC against attacks of opportunity for each alcoholic drink she has consumed during her rage, to a maximum of +1 per four barbarian levels."
#   },
#   "Strength Surge (Ex)": {
#     "Benefit": "The barbarian adds her barbarian level on one Strength check or combat maneuver check, or to her Combat Maneuver Defense when an opponent attempts a maneuver against her. This power is used as an immediate action. Special: This power can only be used once per rage."
#   },
#   "Sunder Enchantment (Su)": {
#     "Prerequisite": "Barbarian 8, spell sunder rage power",
#     "Benefit": "While raging, whenever the barbarian succeeds at a sunder combat maneuver on a magical item, that itemâs magical abilities are suppressed for 1 round, plus 1 round for every 5 points by which her combat maneuver check exceeded the targetâs CMD."
#   },
#   "Terrifying Howl (Ex)": {
#     "Prerequisite": "Barbarian 8, intimidating glare rage power",
#     "Benefit": "The barbarian unleashes a terrifying howl as a standard action. All shaken enemies within 30 feet must make a Will save (DC equal to 10 + 1/2 the barbarian’s level + the barbarian’s Strength modifier) or be panicked for 1d4+1 rounds. Special: Once an enemy has made a save versus terrifying howl (successful or not), it is immune to this power for 24 hours."
#   },
#   "Ultimate Clarity (Su)": {
#     "Prerequisite": "Barbarian 6, moment of clarity, perfect clarity",
#     "Benefit": "Once per rage, the character can refine her senses, seeing through normal and magical darkness (including from magical effects such as blur and displacement), invisibility, and illusions; she can also discern the exact locations of creatures with concealment. This lasts for 1 round. The character does not need to be using moment of clarity to use this rage power."
#   },
#   "Unexpected Strike (Ex)": {
#     "Prerequisite": "Barbarian 8",
#     "Benefit": "The barbarian can make an attack of opportunity against a foe that moves into any square threatened by the barbarian, regardless of whether or not that movement would normally provoke an attack of opportunity. Special: This power can only be used once per rage. "
#   },
#   "Water Sense (Ex)": {
#     "Benefit": "While you are raging and on land, opponents in the water gain only partial cover from you attacks, instead of improved cover. In addition, while on land and targeting an opponent in water, you take only a â1 penalty on attacks with ranged weapons (including thrown weapons) for every 5 feet of water they pass through (instead of the usual â2 penalty for every 5 feet of water)."
#   },
#   "World Serpent Totem (Su)": {
#     "Benefit": "While raging, the barbarian gains a +1 insight bonus to AC against outsiders and aberrations. This bonus increases by +1 for each world serpent rage power the barbarian possesses, excluding this one."
#   },
#   "World Serpent Spirit (Su)": {
#     "Prerequisite": "Barbarian 6, world serpent totem rage power",
#     "Benefit": "While raging, the barbarian considers her weapons to be chaotic-, evil-, good-, and lawful-aligned for the purposes of overcoming damage reduction. She also gains a +1 resistance bonus on saving throws against spells and effects that have an alignment descriptor or come from an outsider or aberration. This bonus increases by +1 for each world serpent rage power the barbarian possesses, excluding this one."
#   },
#   "World Serpent Totem Unity (Su)": {
#     "Prerequisite": "Barbarian 6, world serpent spirit rage power, world serpent totem rage power",
#     "Benefit": "While raging, the barbarian doubles her fast movement bonus to land speed and cannot be knocked prone. She also doubles her world serpent totem insight bonus to AC against attack rolls made by an outsider or aberration to confirm a critical hit against her."
#   },
#   "Rage Powers – Ascension Games, LLC": {},
#   "Lunar Totem (Su)": {
#     "Prerequisite": "Barbarian 6, lesser lunar totem rage power",
#     "Benefit": "While raging, the barbarian increases her bite damage die type with her bite attack by one die type, and the bite deals x3 damage on a critical hit. She always adds her full strength bonus to her bite attack, even when performing a full attack with other weapons. When making a full attack with manufactured weapons and her bite attack (and no other natural weapons), the penalty for using her bite decreases to -2."
#   },
#   "Lunar Totem, Lesser (Su)": {
#     "Prerequisite": "Barbarian 4, must have a bite attack (either from Animal Fury rage power or some other source)",
#     "Benefit": "While raging, the barbarian gains a +1 insight bonus to AC and on saving throws against undead and creatures with the shapechanger subtype. This bonus increases by +1 for each lunar totem rage power the barbarian possesses, excluding this one."
#   },
#   "Lunar Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 10, lunar totem rage power",
#     "Benefit": "When raging, the barbarian gains DR/silver equal to half her barbarian level. She also gains a +4 bonus on saving throws against curses while raging."
#   },
#   "Shadow Totem (Su)": {
#     "Prerequisite": "Barbarian 10, lesser shadow totem rage power",
#     "Benefit": "Once per rage as a swift action, the barbarian can take on a shadowy form until the end of her turn. While in this form, she gains the incorporeal subtype. She takes half damage from corporeal sources as long as they are magic (and no damage from non-magic weapons and objects). Likewise, any magical effects she creates deal only half damage to corporeal creatures. Her manufactured and natural weapons count as ghost touch weapons while incorporeal in this manner. Spells and other effects that do not deal damage function normally. She can pass through a wall or other surface that is up to 5 feet thick per barbarian level while she is incorporeal. She must exit the solid material by the end of her turn."
#   },
#   "Shadow Totem, Lesser (Su)": {
#     "Prerequisite": "Barbarian 6, darkvision 60 ft.",
#     "Benefit": "While raging, each time the barbarian confirms a critical hit her weapon surges with draining shadows. The target must succeed at a Fortitude saving throw (DC = 10 + 1/2 the barbarianâs level + her Constitution modifier) or take 1d4 Strength damage. This is a negative energy effect."
#   },
#   "Shadow Totem, Greater (Su)": {
#     "Prerequisite": "Barbarian 12, shadow totem rage power",
#     "Benefit": "While raging, the barbarian gains the see in darkness ability, allowing her to see perfectly to any distance in darkness, including magical darkness. She is immune to blindness while raging. In addition, the Strength damage she deals on critical hits from her lesser shadow totem increases to 1d6."
#   },
#   "Rage Powers – Forest Guardian Press": {},
#   "Death Totem (Ex)": {
#     "Prerequisite": "Barbarian or savage 6, lesser death totem rage power",
#     "Benefit": "While raging, whenever the barbarian makes a Fortitude saving throw, she can roll twice and choose the best result."
#   },
#   "Death Totem, Lesser (Ex)": {
#     "Prerequisite": "Barbarian or savage",
#     "Benefit": "While raging, the barbarian gains DR 5/bludgeoning and a +2 resistance bonus against cold-based spells and effects."
#   },
#   "Death Totem, Greater (Ex)": {
#     "Prerequisite": "Barbarian or savage 12, lesser death totem and death totem rage powers",
#     "Benefit": "While raging, the death energy that surrounds the barbarian becomes dangerous to any enemy adjacent to the savage. Living enemies adjacent to the barbarian at the start of her turn take 1d8 points of damage from their flesh withering and crumbling to dust. In addition, any living enemy within 10 feet of the barbarian must make a Fortitude saving throw (DC 10 + Â½ the barbarianâs level + the barbarianâs Constitution modifier) or become sickened for 1d6 rounds."
#   },
#   "Rage Powers – Paizo Fans United": {},
#   "Raging Skald (Ex)": {
#     "Prerequisite": "A barbarian must be at least 6th level before selecting this rage power.",
#     "Benefit": "If you unleash a berserker’s cry (with the Berserker’s Cry feat) as you enter a rage or during a rage, the bonus granted increases to +2 and lasts an additional number of rounds equal to your Constitution bonus (if any)."
#   },
#   "Rage Powers – Radiance House": {},
#   "Improved Totemic Alignment (Su)": {
#     "Prerequisite": "Barbarian 6, must possess the totemic sage archetype.",
#     "Benefit": "Whenever you enter a rage while bound to a spirit that belongs to your associated constellation, you may select 1 constellation aspect and gain its benefits for the duration of the rage. You are treated as an occultist with a level equal to your barbarian level for the purpose of this constellation aspect."
#   },
#   "Totemic Mettle (Su)": {
#     "Prerequisite": "Must possess the totemic sage archetype.",
#     "Benefit": "Whenever you enter a rage while bound to a spirit that belongs to your associated constellation, whenever you succeed on a Fortitude save that would normally have a lesser effect on a successful save, you instead completely negate the effect. You are still harmed by the effects that do not allow a saving throw."
#   },
#   "Rage Powers – Samurai Sheepdog": {
#     "Prerequisite": "Roninâs resolve, barbarian level 10th. While raging, a barbarian with this rage power adds the exhausted, frightened, nauseated, and staggered conditions those which she can remove with the roninâs resolve rage power. When she removes the fatigued or exhausted conditions, the barbarian can use her swift action on the same turn to make a single attack at her highest attack bonus against one creature she can reach. As a swift action while raging, a barbarian with this rage power can issue a challenge to one target within sight. If the target is able to reach and attack the barbarian on its next turn without putting itself directly in harmâs way, it must either do so or become demoralized as if the barbarian successfully intimidated it and beat the DC by 1d10 for every two roninâs instinct rage powers the barbarian possesses."
#   }
# }
